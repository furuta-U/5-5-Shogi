# %%
#!rm -rf *
# !nvidia-smi

from google.colab import drive
drive.mount('/content/drive')

import os

print("カレントワーキングディレクトリは[" + os.getcwd() + "]です")

_colab_dir = "/content/drive/MyDrive/Colab Notebooks/5_5_Shogi"
os.chdir(_colab_dir)
print("カレントワーキングディレクトリは[" + os.getcwd() + "]です")

# %%
# !nvidia-smi
# !python train_cycle.py
